# %% [markdown]
# # Google Vids Automation Pipeline with Playwright
#
# This notebook installs all dependencies and runs the automation script to:
# 1. Fetch prompts from Google Sheets.
# 2. Automate browser to generate 3 videos.
# 3. Merge them using FFmpeg.
# 4. Upload the final video to Google Drive.

# %% [markdown]
# ### Step 1: Install Dependencies

# %%
# !apt-get update && apt-get install -y ffmpeg
# !pip install playwright pandas google-api-python-client google-auth-httplib2 google-auth-oauthlib
# !playwright install chromium
# !playwright install-deps chromium

# %% [markdown]
# ### Step 2: Upload Config and Authentication Files
#
# Upload the following files to your Colab directory:
# - `config.json` (configured with sheet_id, drive_folder_id, etc.)
# - `service_account.json` (Google APIs service account key file)
# - `cookies.json` (exported cookies from a logged-in browser session)

# %% [markdown]
# ### Step 3: Run the Automation Pipeline

# %%
# !python main.py
