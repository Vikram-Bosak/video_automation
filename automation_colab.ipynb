# %% [markdown]
# ## Google Vids Automation with Playwright
# This notebook installs Playwright and runs the automation script.

# %%
# !pip install playwright pandas
# !playwright install chromium
# !playwright install-deps

# %% [markdown]
# ### Run the Automation Script
# Make sure your `prompts.csv` is uploaded to the Colab environment.

# %%
# !python main.py
